# %%
## PDF extraction
## Camelot
## Tabula
## Pypdf2
# pip install camelot

# %%
import camelot
file = 'Clusters.pdf'
# extract all the tables in the PDF file
tables = camelot.read_pdf(file)
# number of tables extracted
print("Total tables extracted:", tables.n)
# Out:
# Total tables extracted: 1

# %%
# print the first table as Pandas DataFrame
print(tables[0].df)
# Out:
#             0                                                  1  \
# 0   Sl. \nNo.                      Name of the Cluster (Product)
# 1           1                   Food Processing Cluster, Hathras
# 2           2                Readymade Garments Cluster, Hathras
# 3           3           Ayurvedic Medicine Manufacturing Cluster
# 4           4                            Hing Processing Cluster
# 5           5              Holi Gulal Neel Manufacturing Cluster
# 6           6                       Daal Mill Processing Cluster
# 7           7                               Cold Storage Cluster
# 8           8                 Plastic Mould Maufacturing Cluster
# 9           9           Handicraft (Metal) Manufacturing Cluster
# 10         10                             Dairy Products Cluster
# 11         11                       Carpet Manufacturing Cluster
# 12         12  Artificial Jewellery Manufacturing/Moonga \nMo...
# ...

# %%
# tables.export("vnvj.csv", f="csv", compress=True)

# %%
# pip install pdftables
# pip install tabula

# %%
from tabula import read_pdf
df = read_pdf('Clusters.pdf',pages='all',multiple_tables=True)
# Out:
# Got stderr: Feb 06, 2021 9:55:15 AM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider loadDiskCache
# WARNING: New fonts found, font cache will be re-built
# Feb 06, 2021 9:55:15 AM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider <init>
# WARNING: Building on-disk font cache, this may take a while
# Feb 06, 2021 9:55:20 AM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider <init>
# WARNING: Finished building on-disk font cache, found 181 fonts
# Feb 06, 2021 9:55:20 AM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'Arial-BoldMT' for 'ArialNarrow-Bold'
# Feb 06, 2021 9:55:20 AM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'Arial-BoldMT' for 'ArialNarrow-Bold'
# Feb 06, 2021 9:55:20 AM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'Arial-BoldMT' for 'ArialNarrow-Bold'

# %%
df
# Out:
# [    Sl.              Name of the Cluster (Product)      Location District  \
#  0   No.                                        NaN           NaN      NaN
#  1   NaN                                        NaN           NaN      NaN
#  2   NaN                                        NaN           NaN      NaN
#  3     1           Food Processing Cluster, Hathras       Hathras  Hathras
#  4   NaN                                        NaN           NaN      NaN
#  5     2        Readymade Garments Cluster, Hathras       Hathras  Hathras
#  6   NaN                                        NaN           NaN      NaN
#  7     3   Ayurvedic Medicine Manufacturing Cluster       Hathras  Hathras
#  8   NaN                                        NaN           NaN      NaN
#  9     4                    Hing Processing Cluster       Hathras  Hathras
#  10  NaN                                        NaN           NaN      NaN
# ...

# %%
tabula.convert_into('Clusters.pdf', "iris_all.csv", pages='all')
# Out:
# Got stderr: Feb 07, 2021 10:00:52 AM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'Arial-BoldMT' for 'ArialNarrow-Bold'
# Feb 07, 2021 10:00:52 AM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'Arial-BoldMT' for 'ArialNarrow-Bold'
# Feb 07, 2021 10:00:53 AM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'Arial-BoldMT' for 'ArialNarrow-Bold'

# %%
# importing required modules  
#pip install PyPDF2
import PyPDF2  
    
# creating a pdf file object  
pdfFileObj = open('example2.pdf', 'rb')  
    
# creating a pdf reader object  
pdfReader = PyPDF2.PdfFileReader(pdfFileObj)  
    
# printing number of pages in pdf file  
print(pdfReader.numPages)  
    
# creating a page object  
pageObj = pdfReader.getPage(0)  
    
# extracting text from page  
print(pageObj.extractText())  
    
# closing the pdf file object
pdfFileObj.close()
# Out:
# 16

# %%
# pip install -U selenium
# pip install webdriver_manager

# %%
####  Dyanamic web scrapping

from selenium import webdriver
driver = webdriver.Chrome(executable_path=r'C:\\Users\\raviteja\\Downloads\\chromedriver_win32\\chromedriver.exe')

# %%
# giving input url
driver.get('https://voyant-tools.org/')

# %%
#text input to the box
search_textinput = driver.find_element_by_id('textarea-1015-inputEl')
search_textinput.send_keys('https://personal.ems.psu.edu/~radovic/Chapter17.pdf')
driver.find_element_by_id('button-1021-btnEl').click()

# %%
#  driver.find_elements_by_css_selector('#example_paginate>span>a')
#  driver.find_elements_by_xpath("/html/body/section/div/div/div[2]/div[6]/div[3]/div[2]/table/tbody/tr")
#  /html/body/div[3]/div/div/div[2]/div/div/div/div/div/div[1]/div[1]/div/div/div[1]/div[1]/div[2]/div/a[2]/span/span/span[2]
